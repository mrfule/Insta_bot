# %%
import pprint
from time import sleep
from InstagramAPI import InstagramAPI
import pandas as pd


users_list = []
following_users = []
follower_users = []

class InstaBot:

    def __init__(self):
        self.api = InstagramAPI("***********", "**************") #ID and PPass

    def get_likes_list(self,username):
        api = self.api
        api.login()
        api.searchUsername(username) #Gets most recent post from user
        result = api.LastJson
        username_id = result['user']['pk']
        user_posts = api.getUserFeed(username_id)
        result = api.LastJson
        media_id = result['items'][0]['id']

        api.getMediaLikers(media_id)
        users = api.LastJson['users']
        for user in users:
            users_list.append({'pk':user['pk'], 'username':user['username']})
        bot.follow_users(users_list)


    def follow_users(self,users_list):
        api = self.api
        api.login()
        api.getSelfUsersFollowing()
        result = api.LastJson
        for user in result['users']:
            following_users.append(user['pk'])
        for user in users_list:
            if not user['pk'] in following_users:
                print('Following @' + user['username'])
                api.follow(user['pk'])
                #api.like(user['pk'])
                # set this really long to avoid from suspension
                sleep(10)
            else:
                print('Already following @' + user['username'])
                sleep(1)

    def unfollow_users(self):
        api = self.api
        api.login()
        api.getSelfUserFollowers()
        result = api.LastJson
        for user in result['users']:
            follower_users.append({'pk':user['pk'], 'username':user['username']})

        api.getSelfUsersFollowing()
        result = api.LastJson
        for user in result['users']:
            following_users.append({'pk':user['pk'],'username':user['username']})

        for user in following_users:
            if not user['pk'] in [user['pk'] for user in follower_users]:
                print('Unfollowing @' + user['username'])
                api.unfollow(user['pk'])
                # set this really long to avoid from suspension
                sleep(1) 




bot =  InstaBot()
# To follow users run the function below
# change the username ('instagram') to your target username 
bot.get_likes_list('instagram')

# To unfollow users uncomment and run the function below
#bot.unfollow_users()
# Out:
# Fail to import moviepy. Need only for Video upload.
# Request return 405 error!
# {'message': '', 'status': 'fail'}
# Request return 404 error!
# Login success!
#
# Already following @aayushkapoor1848
# Already following @waseemtariq857
# Already following @sandyygaikwad
# Already following @fariya_7733
# Already following @divyesh_20_05
# Already following @bidhiiiii
# Already following @adnan_rajpoot7
# Already following @souravkalyan_
# Already following @affanansari_0786
# Already following @avantika7023
# Already following @udhaysharma5482
# Already following @abdul_hannan_sheriff
# Already following @kartik_prajapati_143
# Already following @kuldeepkalra96
# Already following @_neo_official_neo_
# Already following @mr_salman_191
# Already following @sandeep_singh_7764
# Already following @mr_flamboy_07
# Already following @jayluu__
# Already following @aakashhhh__
# Already following @rishu308jain_rj
# Already following @atifahmed12khan
# Already following @anjali_rawat17530
# Already following @itzz_rishi_14
# Already following @dhruvilpatel__1373
# Already following @official_ajju_saifi_5273
# Already following @yogeshbatraji
# Already following @mihirjaitly
# Already following @sarvesh1316m
# Already following @rajendramehra440
# Already following @beingrahul222000
# Already following @a.m_a.l_
# Already following @muzahid_ramjan_
# Already following @_mohd_aish_143
# Already following @puja._.kalita
# Already following @ameysingh12.11.2002
# Already following @017pratham
# Already following @anshul_mishra9415
# Already following @parkedium
# Already following @mr_daksh07
# Already following @avinashjedhe
# Already following @luckypardhi1272
# Already following @sagar070400
# Already following @aquib_ali_7
# Already following @oveshansari_
# Already following @divyansh_singer_dk
# Already following @irshadiking
# Already following @the_anirudh.saini
# Already following @_gaurav_gaikwadd_
# Already following @gauravjondhale550
# Already following @vishal.09___
# Already following @patel_harsheel
# Already following @its_patya_11
# Already following @saketsurya_official
# Already following @syed_nawaab
# Already following @_hjadhav_
# Already following @sajal_mangal
# Already following @_abhinavjaiswal
# Already following @celebrites7
# Already following @pravesh_kumar2010
# Already following @sayyad.abrar.7549
# Already following @mayanksolanki5014
# Already following @bobbyzala5958
# Already following @isatyaveersingh
# Already following @smartysam_09
# Already following @_am_it_23
# Already following @munendra8222
# Already following @mr_killer_chouhan
# Already following @akarshit.18
# Already following @modal_king_riya
# Already following @_._.sani.ya._._05
# Already following @aditi.bardhan
# Already following @i_am_ruturaj_007
# Already following @_lovekesh_love
# Already following @mr______azuuu
# Already following @_techboy_5544
# Already following @shurti.roy.16144
# Already following @mohithvarun1
# Already following @muskaan.ib
# Already following @shayar_tera_008
# Already following @bhai143suriya
# Already following @jiya.seth_20
# Already following @pradhnyashil_narnaware_50
# Already following @ahmedjuned64
# Already following @aadil_darbar.111
# Already following @___notty___07
# Already following @iamanaskhan1120002
# Already following @ashish.8050
# Already following @sahil_odiya_47
# Already following @muskan00.001
# Already following @jaberali931
# Already following @kashish_verma_official
# Already following @mr._.pathan._.08
# Already following @kavya.sri9322
# Already following @d.p___battle__ground
# Already following @faruksodagar78
# Already following @gopal_bharwad_0197
# Following @debojyoti._0719
# Following @a_l_i_10_5
# Following @satyam_dass
# Following @the_mustafa_ansari_official
# Following @fuleshprajapati
# Following @aman.goyal04
# Following @shivanshi2917
# Following @mr.parthjadav
# Following @iam_poooja_
# Following @mehtamansi7
# Following @asif.abbu
# Following @kafeel9191
# Following @sagarsingh_18_8_01
# Following @manu._.453
# Following @sanchita_munjal
# Following @rakib_rj_ii
# Following @heartbits88
# Following @the_thought_of_anurag
# Following @__sahana_prakashachar__1
# Following @harsh_pratap_singh_200
# Following @ara.ankitraj
# Following @7588deepak
# Following @chauhan_nehal_1111
# Following @haiderali0202028
# Following @vedant_ambardekar
# Following @jatin_9900
# Following @ar.fahim.9066
# Following @ishan_jagdale03
# Following @_notsohidden_
# Following @khushboo_naazsk
# Following @jagriti3899
# Following @aaashiii103
# Following @ayush14_prasad
# Except on SendRequest (wait 60 sec and resend): HTTPSConnectionPool(host='i.instagram.com', port=443): Max retries exceeded with url: /api/v1/friendships/create/11672260672/ (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E106466688>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     141             conn = connection.create_connection(
# --> 142                 (self.host, self.port), self.timeout, **extra_kw)
#     143
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      97     if err is not None:
# ---> 98         raise err
#      99
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     351         try:
# --> 352             self._validate_conn(conn)
#     353         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     830         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 831             conn.connect()
#     832
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     253         # Add certificate verification
# --> 254         conn = self._new_conn()
#     255
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     150             raise NewConnectionError(
# --> 151                 self, "Failed to establish a new connection: %s" % e)
#     152
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E106466688>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     639             retries = retries.increment(method, url, error=e, _pool=self,
# --> 640                                         _stacktrace=sys.exc_info()[2])
#     641             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     286         if new_retry.is_exhausted():
# --> 287             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     288
#
# MaxRetryError: HTTPSConnectionPool(host='i.instagram.com', port=443): Max retries exceeded with url: /api/v1/friendships/create/11672260672/ (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E106466688>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\InstagramAPI\InstagramAPI.py in SendRequest(self, endpoint, post, login)
#     834                 if (post is not None):
# --> 835                     response = self.s.post(self.API_URL + endpoint, data=post, verify=verify)
#     836                 else:
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in post(self, url, data, json, **kwargs)
#     521
# --> 522         return self.request('POST', url, data=data, json=json, **kwargs)
#     523
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#
# ConnectionError: HTTPSConnectionPool(host='i.instagram.com', port=443): Max retries exceeded with url: /api/v1/friendships/create/11672260672/ (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001E106466688>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-185ce3e38c09> in <module>
#      75 # To follow users run the function below
#      76 # change the username ('instagram') to your target username 'ankitachhetri25',sassy_tanisha ,gima_ashi
# ---> 77 bot.get_likes_list('avneetkaur_13')
#      78
#      79 # To unfollow users uncomment and run the function below
#
# <ipython-input-1-185ce3e38c09> in get_likes_list(self, username)
#      28         for user in users:
#      29             users_list.append({'pk':user['pk'], 'username':user['username']})
# ---> 30         bot.follow_users(users_list)
#      31
#      32
#
# <ipython-input-1-185ce3e38c09> in follow_users(self, users_list)
#      41             if not user['pk'] in following_users:
#      42                 print('Following @' + user['username'])
# ---> 43                 api.follow(user['pk'])
#      44                 #api.like(user['pk'])
#      45                 # set this really long to avoid from suspension
#
# ~\Anaconda3\lib\site-packages\InstagramAPI\InstagramAPI.py in follow(self, userId)
#     741                            'user_id': userId,
#     742                            '_csrftoken': self.token})
# --> 743         return self.SendRequest('friendships/create/' + str(userId) + '/', self.generateSignature(data))
#     744
#     745     def unfollow(self, userId):
#
# ~\Anaconda3\lib\site-packages\InstagramAPI\InstagramAPI.py in SendRequest(self, endpoint, post, login)
#     839             except Exception as e:
#     840                 print('Except on SendRequest (wait 60 sec and resend): ' + str(e))
# --> 841                 time.sleep(60)
#     842
#     843         if response.status_code == 200:
#
# KeyboardInterrupt:
